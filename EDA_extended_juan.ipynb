# %% [markdown]
# # Exploring Tweets data for monitoring Disaster using the exploratory data analysis (EDA) notebook

# %% [markdown]
# #### Introduction
#
# This notebook is the first step in the DS4A Team 155 Project: Exploratory Data Analysis.
# Social Networks have become a crucial communication channel in emergencies since users may report concerning situations in real-time. As a result, more agencies (i.e. disaster relief organizations and news agencies) are interested in monitoring Social Networks such as Twitter. However, tweets from people may or may not be actually realted to disasters. Therefore, machine learning models which predict real-time publication about emergencies and disasters are required.
# From a set of different tweets, this project aims to predict which Tweets are about real disasters and which ones are not.

# %% [markdown]
# ##### The proposed EDA approach to analysis the twitter messages is divided as follows:
# - Import the libraries
# - Input Data
# - Basic Informations
# - Clean the data
# - Feature Engineering
# - Analizing Data
# - Process Data
# - Summary

# %% [markdown]
# ### Import libraries

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (1.21.5)
# Requirement already satisfied: pandas in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (3.5.1)
# Requirement already satisfied: seaborn in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (0.11.2)
# Requirement already satisfied: scikit-learn in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (1.0.2)
# Collecting folium
#   Using cached folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
# Requirement already satisfied: scipy in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (1.7.3)
# Collecting jupyter-dash
#   Using cached jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: plotly in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (5.6.0)
# Requirement already satisfied: nltk in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (3.7)
# Collecting wordcloud
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: branca>=0.3.0 in c:\users\usuario.desktop-gk240nu\appdata\roaming\python\python39\site-packages (from folium->-r requirements.txt (line 6)) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from folium->-r requirements.txt (line 6)) (2.11.3)
# Requirement already satisfied: requests in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from folium->-r requirements.txt (line 6)) (2.27.1)
# Requirement already satisfied: ipython in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from jupyter-dash->-r requirements.txt (line 8)) (8.2.0)
# Requirement already satisfied: ansi2html in c:\users\usuario.desktop-gk240nu\appdata\roaming\python\python39\site-packages (from jupyter-dash->-r requirements.txt (line 8)) (1.7.0)
# Requirement already satisfied: ipykernel in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from jupyter-dash->-r requirements.txt (line 8)) (6.9.1)
# Requirement already satisfied: dash in c:\users\usuario.desktop-gk240nu\appdata\roaming\python\python39\site-packages (from jupyter-dash->-r requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: retrying in c:\users\usuario.desktop-gk240nu\appdata\roaming\python\python39\site-packages (from jupyter-dash->-r requirements.txt (line 8)) (1.3.3)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: nest-asyncio in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from jupyter-dash->-r requirements.txt (line 8)) (1.5.5)
# Requirement already satisfied: flask in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from jupyter-dash->-r requirements.txt (line 8)) (1.1.2)
# Requirement already satisfied: six in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from plotly->-r requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from plotly->-r requirements.txt (line 9)) (8.0.1)
# Requirement already satisfied: tqdm in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from nltk->-r requirements.txt (line 10)) (4.64.0)
# Requirement already satisfied: click in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from nltk->-r requirements.txt (line 10)) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from nltk->-r requirements.txt (line 10)) (2022.3.15)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from jinja2>=2.9->folium->-r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: colorama in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from click->nltk->-r requirements.txt (line 10)) (0.4.4)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\usuario.desktop-gk240nu\appdata\roaming\python\python39\site-packages (from dash->jupyter-dash->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\usuario.desktop-gk240nu\appdata\roaming\python\python39\site-packages (from dash->jupyter-dash->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\usuario.desktop-gk240nu\appdata\roaming\python\python39\site-packages (from dash->jupyter-dash->-r requirements.txt (line 8)) (5.0.0)
# Requirement already satisfied: flask-compress in c:\users\usuario.desktop-gk240nu\appdata\roaming\python\python39\site-packages (from dash->jupyter-dash->-r requirements.txt (line 8)) (1.12)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from flask->jupyter-dash->-r requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from flask->jupyter-dash->-r requirements.txt (line 8)) (2.0.3)
# Requirement already satisfied: brotli in c:\users\usuario.desktop-gk240nu\appdata\roaming\python\python39\site-packages (from flask-compress->dash->jupyter-dash->-r requirements.txt (line 8)) (1.0.9)
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Usuario.DESKTOP-GK240NU\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Usuario.DESKTOP-GK240NU\\AppData\\Local\\Temp\\pip-install-i4uy32y8\\wordcloud_ce9803ea1e6945beb70d9bc6f92b3086\\setup.py'"'"'; __file__='"'"'C:\\Users\\Usuario.DESKTOP-GK240NU\\AppData\\Local\\Temp\\pip-install-i4uy32y8\\wordcloud_ce9803ea1e6945beb70d9bc6f92b3086\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Usuario.DESKTOP-GK240NU\AppData\Local\Temp\pip-wheel-a8odwlv3'
#        cwd: C:\Users\Usuario.DESKTOP-GK240NU\AppData\Local\Temp\pip-install-i4uy32y8\wordcloud_ce9803ea1e6945beb70d9bc6f92b3086\
#   Complete output (20 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\_version.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__main__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#   UPDATING build\lib.win-amd64-3.9\wordcloud/_version.py
#   set build\lib.win-amd64-3.9\wordcloud/_version.py to '1.8.1'
#   running build_ext
#   building 'wordcloud.query_integral_image' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for wordcloud
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Usuario.DESKTOP-GK240NU\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Usuario.DESKTOP-GK240NU\\AppData\\Local\\Temp\\pip-install-i4uy32y8\\wordcloud_ce9803ea1e6945beb70d9bc6f92b3086\\setup.py'"'"'; __file__='"'"'C:\\Users\\Usuario.DESKTOP-GK240NU\\AppData\\Local\\Temp\\pip-install-i4uy32y8\\wordcloud_ce9803ea1e6945beb70d9bc6f92b3086\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Usuario.DESKTOP-GK240NU\AppData\Local\Temp\pip-record-x95r2j3y\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Usuario.DESKTOP-GK240NU\anaconda3\Include\wordcloud'
#          cwd: C:\Users\Usuario.DESKTOP-GK240NU\AppData\Local\Temp\pip-install-i4uy32y8\wordcloud_ce9803ea1e6945beb70d9bc6f92b3086\
#     Complete output (22 lines):
#     running install
#     C:\Users\Usuario.DESKTOP-GK240NU\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\_version.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\__main__.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#     UPDATING build\lib.win-amd64-3.9\wordcloud/_version.py
#     set build\lib.win-amd64-3.9\wordcloud/_version.py to '1.8.1'
#     running build_ext
#     building 'wordcloud.query_integral_image' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\Usuario.DESKTOP-GK240NU\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Usuario.DESKTOP-GK240NU\\AppData\\Local\\Temp\\pip-install-i4uy32y8\\wordcloud_ce9803ea1e6945beb70d9bc6f92b3086\\setup.py'"'"'; __file__='"'"'C:\\Users\\Usuario.DESKTOP-GK240NU\\AppData\\Local\\Temp\\pip-install-i4uy32y8\\wordcloud_ce9803ea1e6945beb70d9bc6f92b3086\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Usuario.DESKTOP-GK240NU\AppData\Local\Temp\pip-record-x95r2j3y\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Usuario.DESKTOP-GK240NU\anaconda3\Include\wordcloud' Check the logs for full command output.
# Requirement already satisfied: jupyter-client<8.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: decorator in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (61.2.0)
# Requirement already satisfied: stack-data in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: backcall in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash->-r requirements.txt (line 8)) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash->-r requirements.txt (line 8)) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash->-r requirements.txt (line 8)) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter-dash->-r requirements.txt (line 8)) (302)
# Requirement already satisfied: wcwidth in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash->-r requirements.txt (line 8)) (0.2.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from requests->folium->-r requirements.txt (line 6)) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from requests->folium->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from requests->folium->-r requirements.txt (line 6)) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from requests->folium->-r requirements.txt (line 6)) (1.26.9)
# Requirement already satisfied: asttokens in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash->-r requirements.txt (line 8)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash->-r requirements.txt (line 8)) (0.2.2)
# Requirement already satisfied: executing in c:\users\usuario.desktop-gk240nu\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash->-r requirements.txt (line 8)) (0.8.3)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py): started
#   Building wheel for wordcloud (setup.py): finished with status 'error'
#   Running setup.py clean for wordcloud
# Failed to build wordcloud
# Installing collected packages: wordcloud, jupyter-dash, folium
#     Running setup.py install for wordcloud: started
#     Running setup.py install for wordcloud: finished with status 'error'

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import nltk # imports the natural language toolkit
nltk.download('punkt')
nltk.download('stopwords')
import string
import plotly
import re

from nltk.stem import PorterStemmer 
from pylab import rcParams
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from collections import Counter
from collections import defaultdict

# Importing the required parameter for plotting 
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Usuario.DESKTOP-
# [nltk_data]     GK240NU\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Usuario.DESKTOP-
# [nltk_data]     GK240NU\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [8], in <cell line: 23>()
#      21 # Importing the required parameter for plotting
#      22 import matplotlib.pyplot as plt
# ---> 23 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# ### Input Data

# %% [markdown]
# The data for this project includes 10876 tweets, divided into two different datasets: a train dataset (7613 tweets) and a test dataset (3263 tweets)
# The datasets have the following columns:

# %% [markdown]
# The train dataset has the following columns:
# - id - a unique identifier for each tweet
# - text - the text of the tweet
# - location - the location the tweet was sent from (may be blank)
# - keyword - a particular keyword from the tweet (may be blank)
# - target - in train.csv only, this feature denotes whether a tweet is about a real disaster (1) or not (0)

# %% [markdown]
# #### Train dataset

# %%
df = pd.read_csv('Data/train.csv', dtype={'id': int, 'keyword': object, 'location': object, 'text': object, 'target': int})
df.head(5)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# #### Test dataset

# %% [markdown]
# The test dataset is the verification values ​​of the prediction model on disasters and does not have the target column in order to validate if the result of the model on the analyzed text is correct (validation of the tweet)

# %%
df_test = pd.read_csv('Data/test.csv', dtype={'id': int, 'keyword': object, 'location': object, 'text': object})
df_test.head(5)
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %% [markdown]
# ### Basic Informations

# %% [markdown]
#  In this case we use the info() function to print a concise summary of a DataFrame.This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage. For our case, we have 7613 rows and 5 columns. Location is the column with the most null values, followed by the Keywords column. Also, we can see that we have two data types: int32 and object.

# %%
df.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int32
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int32
# dtypes: int32(2), object(3)
# memory usage: 238.0+ KB

# %% [markdown]
# The describe() method returns a description of the data in the df. If the df contains numerical data, the description contains: count, mean, std, min, percentiles (25%,50%,75%) and max columns.

# %%
df.describe( )
# Out:
#                  id      target
# count   7613.000000  7613.00000
# mean    5441.934848     0.42966
# std     3137.116090     0.49506
# min        1.000000     0.00000
# 25%     2734.000000     0.00000
# 50%     5408.000000     0.00000
# 75%     8146.000000     1.00000
# max    10873.000000     1.00000

# %% [markdown]
# In our DataFrame, we can find two numerical columns: id & target. For this case, we have complete information for the 7613 tweets (non null values). The mean of the target column is 0.42966, which means that most of the tweets do not correspond to a disaster (0: not disaster, 1: disaster), we can verify this information in the value counts function of the target column, that show us that we have 4342 with “0” target and 3271 with “1” target.

# %%
df["target"].value_counts()
# Out:
# 0    4342
# 1    3271
# Name: target, dtype: int64

# %% [markdown]
# With the function “df.isnull().sum()” we are adding the number of null values ​​that we have in each column. As we mentioned before, the column with the most null values is location with 2533 null values, followed by the Keyword column with 61 null values.

# %%
df.isnull().sum()
# Out:
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %% [markdown]
# ##### Observations
#
# - There is a total of 7613 entries (train)
# - There are numerous blanks in the dataset that need to be replaced with NA

# %% [markdown]
# ### Clean Data

# %% [markdown]
# In the clean data part will be analyzed the characteristics of the information provided. This analysis is done based on the form of the data (uppercase, lowercase, etc.), the missing data, wrongly formatted data (for example, that in the text character cell it has a numeric data, they have special characters or links), the length of the tweet and how many words they have.

# %% [markdown]
# #### Removing rows, which own non-numerical values in the target column

# %% [markdown]
# In this part, we have a dataset that was classified by natural disaster based on a text provided by a tweet. To avoid having data that was not classified in the train part, we remove the data that has no classification with the .notnull() function.

# %%
df[pd.to_numeric(df['target'], errors='coerce').notnull()]
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %% [markdown]
# In the target column, a value other than 1 and 0 may have been entered during the classification stage. In this step, the dataset is filtered only by the values ​​that have a 1 and a 0 in the target.

# %% [markdown]
# #### Removing rows, which have not 1 and 0 values in target column

# %% [markdown]
# In the target column, a value other than 1 and 0 may have been entered during the classification stage. In this step, the dataset is filtered only by the values ​​that have a 1 and a 0 in the target. This step is done focused on the model of not having data that does not have a classification.

# %%
def is_valid_number(x):
    if x == 1 or x == 0:
        return True
    else:
        return True
df[df['target'].apply(lambda x: is_valid_number(x))]
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %% [markdown]
# #### Removing punctuations and numbers

# %% [markdown]
# In this part we will focus on the text column. Within this column, there is the tweet and it is sought to eliminate the punctuation marks and numbers, which add length to the text but do not add value to the message.

# %%
df['text_clean'] = df['text'].str.replace('[^\w\s]', '', regex=True).str.replace('\d+', '', regex=True)
df.head(5)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target                                         text_clean
# 0       1  Our Deeds are the Reason of this earthquake Ma...
# 1       1              Forest fire near La Ronge Sask Canada
# 2       1  All residents asked to shelter in place are be...
# 3       1   people receive wildfires evacuation orders in...
# 4       1  Just got sent this photo from Ruby Alaska as s...

# %% [markdown]
# #### Removing uppercase

# %% [markdown]
# The characters have variations of uppercase and lowercase, but represent the same word. To avoid this situation, in this part of the code for the entire text column we convert the entire text string to lowercase using the "lower" function

# %%
df['text_clean']=df['text_clean'].apply(lambda x: x.lower())
df.head(5)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target                                         text_clean
# 0       1  our deeds are the reason of this earthquake ma...
# 1       1              forest fire near la ronge sask canada
# 2       1  all residents asked to shelter in place are be...
# 3       1   people receive wildfires evacuation orders in...
# 4       1  just got sent this photo from ruby alaska as s...

# %% [markdown]
# #### Removing hyperlink

# %% [markdown]
# In this part we will focus on the text column. Within this column, there is the tweet and it is sought to eliminate hiperlink, which add length to the text but does not add value to the message. We use the regex library  and replace all the possible hyperlink

# %%
df['text_clean']=df['text_clean'].apply(lambda x:re.sub('https?://\S+|www\.\S+', '', x))
df.head(5)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target                                         text_clean
# 0       1  our deeds are the reason of this earthquake ma...
# 1       1              forest fire near la ronge sask canada
# 2       1  all residents asked to shelter in place are be...
# 3       1   people receive wildfires evacuation orders in...
# 4       1  just got sent this photo from ruby alaska as s...

# %% [markdown]
# #### Removing square brackets

# %% [markdown]
# In this part we will focus on the text column. Within this column, there is the tweet and it is sought to eliminate the brackets, which add length to the text but does not add value to the message. We use the regex library  and replace all the possible hyperlink

# %%
df['text_clean']=df['text_clean'].apply(lambda x:re.sub('\[.*?\]', '', x))
df['text_clean']=df['text_clean'].apply(lambda x:re.sub('<.*?>+', '', x))
df.head(5)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target                                         text_clean
# 0       1  our deeds are the reason of this earthquake ma...
# 1       1              forest fire near la ronge sask canada
# 2       1  all residents asked to shelter in place are be...
# 3       1   people receive wildfires evacuation orders in...
# 4       1  just got sent this photo from ruby alaska as s...

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Counting the number of words

# %% [markdown]
# Using a lambda function, we split the text in the “text clean” column and count how many words there are in each tweet. For example, the tweet with id=1 has 13 words.

# %%
df['word_count'] = df['text_clean'].apply(lambda x: len(x.split()))
df.head(5)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target                                         text_clean  word_count
# 0       1  our deeds are the reason of this earthquake ma...          13
# 1       1              forest fire near la ronge sask canada           7
# 2       1  all residents asked to shelter in place are be...          22
# 3       1   people receive wildfires evacuation orders in...           7
# 4       1  just got sent this photo from ruby alaska as s...          16

# %% [markdown]
# #### Adding the text length

# %% [markdown]
# Similarly, we can calculate how many characters there are in each tweet, applying just the len(x) function. The tweet with id=1 has 68 characters:

# %%
df['size'] = df['text_clean'].apply(lambda x: len(x))
df.head(5)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target                                         text_clean  word_count  size
# 0       1  our deeds are the reason of this earthquake ma...          13    68
# 1       1              forest fire near la ronge sask canada           7    37
# 2       1  all residents asked to shelter in place are be...          22   130
# 3       1   people receive wildfires evacuation orders in...           7    58
# 4       1  just got sent this photo from ruby alaska as s...          16    86

# %% [markdown]
# ### Analizing Data

# %% [markdown]
# #### Number of Tweets with disasters (1) and non-disasters (0)

# %% [markdown]
# We can plot a bar graph to check how many tweets are disasters and how many are not. We take the target column to a new dataframe and plot the graph using seaborn:

# %%
df_target = df['target'].value_counts().to_frame()

## seaborn barplot to display barchart
rcParams['figure.figsize'] = 5, 4
sns.barplot(data=df_target, x=df_target.index, y="target")
# Out:
# <AxesSubplot:ylabel='target'>

# %% [markdown]
# We can see that there are more non-disaster tweets (0).

# %% [markdown]
# #### Top twenty locations

# %% [markdown]
# Although not every tweet has location information, we can investigate which cities or countries are more represented in the dataset. We calculate the value counts for the column “location” and plot the top 20 results in a bar graph.

# %%
top_location = df["location"].value_counts().head(20)
top_location.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The top locations are “USA”, “New York”, “United States” and “London”. Clearly, USA and United States refer to the same country, and New York is a city in that country. Therefore, it is a good idea to standardize the locations, specially the ones that refer to the same country (USA = United States). However, we will probably leave both cities and countries in our location column, as it is good to have location up to a city scale, even though some of the tweets have only the country and there is no way to find from which city they were written.

# %% [markdown]
# #### Histogram of the text size

# %% [markdown]
# In the following histogram, we can see the distribution of the length (characters) of the tweets, which is left-skewed. As expected, there are very few short tweets, and most of them have approximately 120 characters. The maximum number of characters is 140, and therefore we can deduce that this dataset has tweets that were sent before november 2017, when twitter decided to double the character limit from 140 to 280 characters.

# %%
df['size'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Histogram of the number words

# %% [markdown]
# Conversely, the following histogram of the amount of words in the tweets is relatively symmetric, although it has a bit of a longer right tail. We can see that most tweets have between 10 and 18 words.

# %%
df['word_count'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Histogram of the average word length

# %% [markdown]
# Finally, we plot a histogram of the average word length in each tweet. We can see that it is a right-skewed distribution and that the average word length in most tweets is 5 to 6 characters.

# %%
df['text_clean'].str.split().apply(lambda x : [len(i) for i in x]).map(lambda x: np.mean(x)).hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Process data

# %% [markdown]
# #### Word tokenization

# %%
AllReviews = df['text_clean']
AllReviews.head()
# Out:
# 0    our deeds are the reason of this earthquake ma...
# 1                forest fire near la ronge sask canada
# 2    all residents asked to shelter in place are be...
# 3     people receive wildfires evacuation orders in...
# 4    just got sent this photo from ruby alaska as s...
# Name: text_clean, dtype: object

# %%
review_words_lengths = AllReviews.apply(lambda x: len(nltk.word_tokenize(x)))

# %% [markdown]
# #### Sentences with two words

# %%
AllReviews[review_words_lengths[review_words_lengths == 2].index].head(5)
# Out:
# 22                       love skiing
# 30                           the end
# 113    aftershock httpstcoxmwodfmtui
# 131      aftershock httpstcojvppkhjy
# 276                apocalypse please
# Name: text_clean, dtype: object

# %% [markdown]
# #### Max and min values in the number of words

# %%
print("Minimun number of words", min(review_words_lengths))
print("Maximum number of words", max(review_words_lengths))
# Out:
# Minimun number of words 1
# Maximum number of words 31

# %% [markdown]
# #### Histogram of the tokenization words

# %%
## Setting the resolution for better clarity 
review_words_lengths.hist(bins = 25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The results of the tokenization process show that there is a significant concentration in the groups of tweets that have a number of words between 10 and 20 words. Being the lengths of 13 and 14 where the majority of the tweets are found, with more than 1000 records only in those two lengths. In general terms, it could be said that most of the tweets don’t really correspond to natural disasters, because in the middle of an emergency there is not enough time to write a very long tweet.

# %% [markdown]
# #### Histogram of the tokenization words for disaster

# %%
disaster = df[df.target == 1] 
Reviews_disaster = disaster['text_clean'] 
review_words_lengths_disaster = Reviews_disaster.apply(lambda x: len(nltk.word_tokenize(x)))
review_words_lengths_disaster.hist(bins = 25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This histogram shows what was intuited in the analysis of the previous histogram. Analyzing only the tokenization of tweets that actually correspond to disasters, the distribution of most tweets leans towards shorter lengths than those shown in the histogram without the filtered data.
#
# In conclusion, the precaution that must be taken when training the model must be taken into account, due to the little information that a tweet that corresponds to disaster can contain (remember that the stop words are generating noise when generating the histogram).
# In the word cloud diagram that corresponds to positive tweets for disaster, it can be seen that there are keywords that indicate what may be the most recurrent disasters or events in the dataset, such as fires, landslides, terrorist attacks and accidents. Noise can also be evidenced in the data generated by the stop words.

# %% [markdown]
# #### Text visualization with word clouds

# %%
def word_cloud_rating(data, target_value, title, columna):
    
    data_filtered = data[data.target == target_value] #filtering according to the star value
    Reviews = data_filtered[columna]

    Reviews_text = ' '.join(Reviews.values) #joining all the words together

    # Creating a word cloud object
    wordcloud = WordCloud(max_font_size=100, max_words=100, background_color="white",scale = 10,width=800, height=400).generate(Reviews_text)

    # Plotting the generated word cloud

    plt.figure(figsize=(8, 19))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.title(title,fontsize=20);
    plt.axis("off")
    plt.show()
    
##### Filtering by target equal 1    
word_cloud_rating(df, 1, 'Disaster Tweets', "text_clean")

##### Filtering by target equal 0    
word_cloud_rating(df, 0, 'Non-Disaster Tweets', "text_clean")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 20>()
#      17     plt.show()
#      19 ##### Filtering by target equal 1
# ---> 20 word_cloud_rating(df, 1, 'Disaster Tweets', "text_clean")
#      22 ##### Filtering by target equal 0
#      23 word_cloud_rating(df, 0, 'Non-Disaster Tweets', "text_clean")
#
# Input In [34], in word_cloud_rating(data, target_value, title, columna)
#       6 Reviews_text = ' '.join(Reviews.values) #joining all the words together
#       8 # Creating a word cloud object
# ----> 9 wordcloud = WordCloud(max_font_size=100, max_words=100, background_color="white",scale = 10,width=800, height=400).generate(Reviews_text)
#      11 # Plotting the generated word cloud
#      13 plt.figure(figsize=(8, 19))
#
# NameError: name 'WordCloud' is not defined

# %% [markdown]
#  In the word cloud diagram that corresponds to positive tweets for disaster, it can be seen that there are keywords that indicate what may be the most recurrent disasters or events in the dataset, such as fires, landslides, terrorist attacks and accidents. Noise can also be evidenced in the data generated by the stop words.
# As expected, in the tweets that are not related to disasters, there are no words that have a critical meaning or a disaster relationship, for instance, words like people, love, world and time are the most relevant.

# %% [markdown]
# #### Most common keywords

# %%
common_keywords = df["keyword"].value_counts().to_frame().head(15)
fig = plt.figure(figsize=(10,4))
sns.barplot(data=common_keywords, x=common_keywords.index, y="keyword",palette="magma")
plt.ylim(38, 46)
plt.title("Most common keywords")
plt.xticks(rotation=55, size=11);

# %% [markdown]
#  In the analysis of the distribution of the data in terms of keywords, there is a main word that is transversal to any catastrophic event and that is "fatalities". Then, there are the words related to events that have the component of rain. There are some words that have an important role and that are related to the impact generated by disasters, words like fear, damage, injuries, etc.

# %% [markdown]
# #### Most commun words in the tweets

# %%
counter = Counter()
for text in df['text'].values:
    for word in text.split():
        counter[word] += 1
counter.most_common(20)
# Out:
# [('the', 2575),
#  ('a', 1845),
#  ('to', 1805),
#  ('in', 1757),
#  ('of', 1722),
#  ('and', 1302),
#  ('I', 1197),
#  ('for', 820),
#  ('is', 814),
#  ('on', 773),
#  ('-', 763),
#  ('you', 632),
#  ('The', 552),
#  ('my', 549),
#  ('with', 508),
#  ('that', 492),
#  ('at', 485),
#  ('by', 469),
#  ('it', 433),
#  ('from', 372)]

# %%
data = dict(sorted(counter.items(), key = lambda x: x[1] ,reverse = True)[:10])
words = list(data.keys())
frequency = list(data.values())
frequency

fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (3, 7))
ax.set_facecolor('black')
ax = sns.barplot(x = frequency, y = words, color = '#8699A7', edgecolor = 'white', linewidth = 2)
plt.title('Word Frequency', fontsize = 12)
plt.xlabel('Frequency', fontsize = 12)
plt.ylabel('Words', fontsize = 12)
plt.xticks(size = 12)
plt.yticks(size = 12)
bbox_args = dict(boxstyle = 'round', fc = '0.9')
for p in ax.patches:
    width = p.get_width()
    plt.text(9.5 + p.get_width(), p.get_y() + 0.5 * p.get_height(), '{:1.0f}'.format(width), 
             ha = 'center', 
             va = 'center', 
             color = 'black', 
             bbox = bbox_args, 
             fontsize = 11)
plt.show()

# %% [markdown]
# Finally, in the analysis of the frequency of each word, it is evident that the largest amounts are found in the stop words. This confirms what was previously mentioned, when it was said that when these types of words are not removed, noise is created in the data that biases any analysis that one wants to carry out on the composition of the words.

# %%
 #  ___                   ____                   _     _         _____   ____       _    
 # |_ _|  _ __           |  _ \    ___   _ __   | |_  | |__     | ____| |  _ \     / \   
 #  | |  | '_ \   _____  | | | |  / _ \ | '_ \  | __| | '_ \    |  _|   | | | |   / _ \  
 #  | |  | | | | |_____| | |_| | |  __/ | |_) | | |_  | | | |   | |___  | |_| |  / ___ \ 
 # |___| |_| |_|         |____/   \___| | .__/   \__| |_| |_|   |_____| |____/  /_/   \_\
 #                                      |_|

# %% [markdown]
# #  Removing stop words in the tweets

# %%
stop_words = set(stopwords.words('english'))

# %%
df['tokenizado'] = df['text_clean'].apply(lambda x: word_tokenize(x))
df.head(3)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
#
#    target                                         text_clean  word_count  \
# 0       1  our deeds are the reason of this earthquake ma...          13
# 1       1              forest fire near la ronge sask canada           7
# 2       1  all residents asked to shelter in place are be...          22
#
#    size                                         tokenizado
# 0    68  [our, deeds, are, the, reason, of, this, earth...
# 1    37      [forest, fire, near, la, ronge, sask, canada]
# 2   130  [all, residents, asked, to, shelter, in, place...

# %%
df['text_clean_non_stopwords'] = df['tokenizado'].apply(lambda x: ' '.join([word for word in x if word not in stop_words]))
df.head(3)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
#
#    target                                         text_clean  word_count  \
# 0       1  our deeds are the reason of this earthquake ma...          13
# 1       1              forest fire near la ronge sask canada           7
# 2       1  all residents asked to shelter in place are be...          22
#
#    size                                         tokenizado  \
# 0    68  [our, deeds, are, the, reason, of, this, earth...
# 1    37      [forest, fire, near, la, ronge, sask, canada]
# 2   130  [all, residents, asked, to, shelter, in, place...
#
#                             text_clean_non_stopwords
# 0       deeds reason earthquake may allah forgive us
# 1              forest fire near la ronge sask canada
# 2  residents asked shelter place notified officer...

# %% [markdown]
# ###  Comparing disaster vs non-disaster without stop words

# %%
##### Filtering by target equal 1    
word_cloud_rating(df, 1, 'Disaster Tweets', "text_clean_non_stopwords")

##### Filtering by target equal 0    
word_cloud_rating(df, 0, 'Non-Disaster Tweets', "text_clean_non_stopwords")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 2>()
#       1 ##### Filtering by target equal 1
# ----> 2 word_cloud_rating(df, 1, 'Disaster Tweets', "text_clean_non_stopwords")
#       4 ##### Filtering by target equal 0
#       5 word_cloud_rating(df, 0, 'Non-Disaster Tweets', "text_clean_non_stopwords")
#
# Input In [34], in word_cloud_rating(data, target_value, title, columna)
#       6 Reviews_text = ' '.join(Reviews.values) #joining all the words together
#       8 # Creating a word cloud object
# ----> 9 wordcloud = WordCloud(max_font_size=100, max_words=100, background_color="white",scale = 10,width=800, height=400).generate(Reviews_text)
#      11 # Plotting the generated word cloud
#      13 plt.figure(figsize=(8, 19))
#
# NameError: name 'WordCloud' is not defined

# %% [markdown]
# ### Most commun word without stop words

# %%
def palabras_principales(numero_palabras, df, columna, target_value):
    counter = Counter()
    for text in  df[df.target == target_value]["text_clean_non_stopwords"].values:
        for word in text.split():
            counter[word] += 1
    data = dict(sorted(counter.items(), key = lambda x: x[1] ,reverse = True)[:numero_palabras])
    words = list(data.keys())
    frequency = list(data.values())
    return frequency, words

# %%
frequency_dis, words_dis = palabras_principales(10, df, "text_clean_non_stopwords", 1)
frequency_non, words_non = palabras_principales(10, df, "text_clean_non_stopwords", 0)

# %%
fig = plt.figure()
plt.barh(frequency_dis, words_dis)
plt.title('Most commun word without stop words')
plt.ylabel('Product')
plt.xlabel('Quantity')
plt.show()

# %%
disaster = df[df.target == 1] 
non_disaster = df[df.target == 0] 

# disaster['word_count'] = disaster['text_clean'].apply(lambda x: len(x.split()))
# non_disaster['word_count'] = non_disaster['text_clean'].apply(lambda x: len(x.split()))

# %% [markdown]
# # TOP 1% HIGH FREQUENCY WORDS

# %%
from collections import Counter

all_reviews_text = ' '.join(df['text_clean_non_stopwords'])
tokenized_words = nltk.word_tokenize(all_reviews_text)
word_freq = Counter(tokenized_words)

len(word_freq)
# Out:
# 21701

# %%
## Therefore, top 1% is ~ words
word_freq.most_common(217)
# Out:
# [('like', 345),
#  ('amp', 300),
#  ('im', 299),
#  ('fire', 250),
#  ('get', 229),
#  ('new', 224),
#  ('via', 220),
#  ('news', 197),
#  ('people', 196),
#  ('one', 192),
#  ('dont', 191),
#  ('us', 170),
#  ('video', 165),
#  ('emergency', 157),
#  ('disaster', 152),
#  ('police', 140),
#  ('would', 131),
#  ('still', 129),
#  ('time', 126),
#  ('body', 124),
#  ('got', 123),
#  ('burning', 120),
#  ('back', 119),
#  ('crash', 118),
#  ('california', 117),
#  ('storm', 117),
#  ('suicide', 116),
#  ('day', 113),
#  ('know', 112),
#  ('man', 110),
#  ('buildings', 110),
#  ('rt', 107),
#  ('first', 107),
#  ('see', 105),
#  ('pm', 105),
#  ('going', 103),
#  ('world', 103),
#  ('bomb', 103),
#  ('cant', 102),
#  ('nuclear', 101),
#  ('love', 100),
#  ('fires', 100),
#  ('attack', 99),
#  ('youtube', 98),
#  ('two', 97),
#  ('dead', 96),
#  ('killed', 96),
#  ('go', 95),
#  ('train', 93),
#  ('car', 91),
#  ('full', 91),
#  ('war', 90),
#  ('hiroshima', 90),
#  ('may', 88),
#  ('families', 88),
#  ('life', 87),
#  ('accident', 87),
#  ('today', 87),
#  ('good', 87),
#  ('think', 86),
#  ('say', 85),
#  ('watch', 85),
#  ('many', 84),
#  ('u', 84),
#  ('last', 83),
#  ('could', 81),
#  ('years', 80),
#  ('want', 80),
#  ('na', 79),
#  ('home', 77),
#  ('way', 77),
#  ('make', 76),
#  ('collapse', 75),
#  ('work', 74),
#  ('look', 73),
#  ('best', 73),
#  ('mh', 73),
#  ('even', 72),
#  ('need', 72),
#  ('help', 71),
#  ('really', 71),
#  ('death', 71),
#  ('army', 71),
#  ('mass', 71),
#  ('wildfire', 71),
#  ('year', 70),
#  ('please', 70),
#  ('lol', 70),
#  ('another', 69),
#  ('take', 69),
#  ('bombing', 69),
#  ('right', 68),
#  ('youre', 67),
#  ('school', 66),
#  ('black', 66),
#  ('hot', 66),
#  ('forest', 65),
#  ('û_', 65),
#  ('fatal', 65),
#  ('much', 64),
#  ('northern', 64),
#  ('w', 62),
#  ('great', 62),
#  ('obama', 62),
#  ('let', 62),
#  ('water', 62),
#  ('legionnaires', 62),
#  ('never', 61),
#  ('wreck', 61),
#  ('homes', 61),
#  ('bomber', 61),
#  ('live', 60),
#  ('city', 60),
#  ('latest', 60),
#  ('every', 59),
#  ('old', 59),
#  ('read', 58),
#  ('atomic', 58),
#  ('god', 57),
#  ('said', 57),
#  ('thats', 57),
#  ('flames', 57),
#  ('fear', 57),
#  ('floods', 57),
#  ('flood', 56),
#  ('getting', 56),
#  ('shit', 56),
#  ('come', 56),
#  ('top', 55),
#  ('feel', 55),
#  ('near', 54),
#  ('ever', 54),
#  ('content', 54),
#  ('damage', 53),
#  ('everyone', 53),
#  ('japan', 53),
#  ('oil', 53),
#  ('found', 52),
#  ('hit', 52),
#  ('since', 52),
#  ('hope', 52),
#  ('military', 52),
#  ('coming', 51),
#  ('weather', 51),
#  ('without', 51),
#  ('injured', 51),
#  ('ass', 51),
#  ('earthquake', 50),
#  ('evacuation', 50),
#  ('flooding', 50),
#  ('night', 50),
#  ('next', 50),
#  ('truck', 50),
#  ('th', 50),
#  ('debris', 50),
#  ('well', 50),
#  ('malaysia', 50),
#  ('stop', 49),
#  ('state', 49),
#  ('plan', 49),
#  ('smoke', 48),
#  ('set', 48),
#  ('times', 48),
#  ('little', 48),
#  ('cause', 48),
#  ('gon', 47),
#  ('movie', 47),
#  ('wounded', 47),
#  ('cross', 47),
#  ('confirmed', 47),
#  ('thunderstorm', 47),
#  ('severe', 47),
#  ('always', 46),
#  ('st', 46),
#  ('check', 46),
#  ('fucking', 46),
#  ('face', 46),
#  ('looks', 46),
#  ('food', 46),
#  ('wild', 46),
#  ('reddit', 46),
#  ('theres', 45),
#  ('heat', 45),
#  ('bad', 45),
#  ('natural', 45),
#  ('sinking', 45),
#  ('thunder', 45),
#  ('rain', 44),
#  ('also', 44),
#  ('bloody', 44),
#  ('family', 44),
#  ('services', 44),
#  ('hes', 44),
#  ('liked', 44),
#  ('warning', 44),
#  ('weapon', 44),
#  ('says', 44),
#  ('fall', 44),
#  ('weapons', 44),
#  ('lightning', 44),
#  ('injuries', 44),
#  ('loud', 44),
#  ('ive', 43),
#  ('screaming', 43),
#  ('house', 43),
#  ('change', 43),
#  ('high', 43),
#  ('missing', 43),
#  ('made', 43),
#  ('bags', 43),
#  ('evacuate', 43),
#  ('spill', 43),
#  ('summer', 42),
#  ('end', 42),
#  ('head', 42),
#  ('free', 42),
#  ('murder', 42)]

# %% [markdown]
# # BOTTOM 1% LOW FREQUENCY WORDS

# %%
## Similarly, bottom 1% is ~463 words
word_freq.most_common()[-217:-1]
# Out:
# [('dauntedpsyche', 1),
#  ('gently', 1),
#  ('dabbed', 1),
#  ('rag', 1),
#  ('crawling', 1),
#  ('hea', 1),
#  ('rams', 1),
#  ('soldi', 1),
#  ('httptcoobszybaj', 1),
#  ('sorrower', 1),
#  ('httptcolyjioi', 1),
#  ('httptcoutmwmjirty', 1),
#  ('squeaver', 1),
#  ('hangin', 1),
#  ('buck', 1),
#  ('watchin', 1),
#  ('septic', 1),
#  ('captainn_morgan', 1),
#  ('destiel', 1),
#  ('httpstcomkxuxozt', 1),
#  ('gazette', 1),
#  ('httptcojhcrtvf', 1),
#  ('scratching', 1),
#  ('pedals', 1),
#  ('aquahttptcoscghlpiq', 1),
#  ('memenaar', 1),
#  ('kindof', 1),
#  ('restrospect', 1),
#  ('_pokemoncards_', 1),
#  ('icequeenfroslas', 1),
#  ('ranking', 1),
#  ('artectura', 1),
#  ('nå¼', 1),
#  ('florence', 1),
#  ('httpstcoleblvf', 1),
#  ('gimp', 1),
#  ('newave', 1),
#  ('httptcoxqlgwoymt', 1),
#  ('httptcohqnxqmeg', 1),
#  ('progressives', 1),
#  ('ûïnewsû', 1),
#  ('livestreaming', 1),
#  ('girlthatsrio', 1),
#  ('uncles', 1),
#  ('georgefoster', 1),
#  ('edmund', 1),
#  ('fitzgerald', 1),
#  ('httptcowrgankom', 1),
#  ('httptcotzsqeesd', 1),
#  ('blockage', 1),
#  ('woodward', 1),
#  ('northbound', 1),
#  ('davison', 1),
#  ('shoalstraffic', 1),
#  ('blinker', 1),
#  ('misscharleywebb', 1),
#  ('httptcouuwfgm', 1),
#  ('greer', 1),
#  ('httptconqzbmzuly', 1),
#  ('amazondeals', 1),
#  ('skylanders', 1),
#  ('httptcopmbuzfgin', 1),
#  ('staged', 1),
#  ('locomotive', 1),
#  ('httptcoeixhthm', 1),
#  ('ralph', 1),
#  ('titortau', 1),
#  ('lynch', 1),
#  ('factchecking', 1),
#  ('ombudsmanship', 1),
#  ('raineishida', 1),
#  ('lolim', 1),
#  ('nervous', 1),
#  ('takeaways', 1),
#  ('amazonûªs', 1),
#  ('magnificent', 1),
#  ('httptcodbdwtocgxf', 1),
#  ('httptcosfakqnveta', 1),
#  ('httptcoyopeypjkb', 1),
#  ('httptcogrhzlk', 1),
#  ('httptcocarmqivkwu', 1),
#  ('httptcocsmyauna', 1),
#  ('janeenorman', 1),
#  ('probability', 1),
#  ('httptcocdohgnjmst', 1),
#  ('httptcovogrfn', 1),
#  ('httptcoxbzwyhct', 1),
#  ('kuala', 1),
#  ('lumpur', 1),
#  ('httptcouqvadfbca', 1),
#  ('httptcokacrlpjcl', 1),
#  ('httptcoyjjbntcazy', 1),
#  ('httptcokfzvmxjst', 1),
#  ('httptcoptevymt', 1),
#  ('ajabrown', 1),
#  ('httptcowmnbitap', 1),
#  ('httptcosfrgnwo', 1),
#  ('httptcoledmvezcol', 1),
#  ('ministersays', 1),
#  ('buzzfeed', 1),
#  ('httptcoqsiplcfa', 1),
#  ('httptcobptzamjlk', 1),
#  ('httptcoljylxzfbi', 1),
#  ('firstever', 1),
#  ('vanished', 1),
#  ('httptcovazpgftmu', 1),
#  ('httptcoqnvxjpalj', 1),
#  ('httptcodtfswnjzil', 1),
#  ('httptcoedekrmqtpq', 1),
#  ('httptcoiidkcjsbx', 1),
#  ('najibrazak', 1),
#  ('malaysiaairlines', 1),
#  ('httptcoubwozut', 1),
#  ('httptcozvdgiyowf', 1),
#  ('httptcojryodr', 1),
#  ('httptcorpdxfkhdq', 1),
#  ('httpstcoakmihlris', 1),
#  ('httptcokukmala', 1),
#  ('httptcoyixrhqgb', 1),
#  ('httptcomssqsvnbm', 1),
#  ('httptconnyfdl', 1),
#  ('httptcoyixfghdy', 1),
#  ('yahoonewsdigest', 1),
#  ('httptcoebpybfhd', 1),
#  ('julian_lage', 1),
#  ('grantgordy', 1),
#  ('rossmartin', 1),
#  ('pastie', 1),
#  ('industrial', 1),
#  ('stare', 1),
#  ('costing', 1),
#  ('apiece', 1),
#  ('httptcodtdidinqyf', 1),
#  ('igerûªs', 1),
#  ('disneyûªs', 1),
#  ('ûòåêcnbc', 1),
#  ('httptcopnlucerpx', 1),
#  ('liv', 1),
#  ('oliviaapalmerr', 1),
#  ('thatswhatfriendsarefor', 1),
#  ('audi', 1),
#  ('httpstcogrzrnqj', 1),
#  ('httptcosfjdnvdw', 1),
#  ('kunstler', 1),
#  ('httptcoacitemt', 1),
#  ('residualincome', 1),
#  ('mlm', 1),
#  ('httptcowqjlshwg', 1),
#  ('httptcodeqqopspf', 1),
#  ('httptcolbkvfqrpgt', 1),
#  ('httptcorvauvtp', 1),
#  ('coleslaw', 1),
#  ('httptcosijnbmczij', 1),
#  ('exotic', 1),
#  ('httptcojxeujps', 1),
#  ('tunes_wgg', 1),
#  ('__ohhmyjoshh', 1),
#  ('stevenrulles', 1),
#  ('httptcoqvxvqtpz', 1),
#  ('httptcovuwbsrsnry', 1),
#  ('riddler', 1),
#  ('earlyexit', 1),
#  ('presidential', 1),
#  ('marynmck', 1),
#  ('adorable', 1),
#  ('httptcogprayyc', 1),
#  ('topnews', 1),
#  ('caitsroberts', 1),
#  ('barra', 1),
#  ('kirafrog', 1),
#  ('mount_wario', 1),
#  ('httptcodalztonc', 1),
#  ('httptcoudxobyua', 1),
#  ('httptcoueatxrhys', 1),
#  ('httptcoyisyzkc', 1),
#  ('widda', 1),
#  ('goner', 1),
#  ('jt_ruff', 1),
#  ('cameronhacker', 1),
#  ('shoutout', 1),
#  ('fx', 1),
#  ('httptcoennullkzm', 1),
#  ('engineshed', 1),
#  ('httptcoomnbatjeao', 1),
#  ('httptconrbnhmtd', 1),
#  ('httptcoaawzxykles', 1),
#  ('httptcorsmvgdxriv', 1),
#  ('boxes', 1),
#  ('exploding', 1),
#  ('gameofkittens', 1),
#  ('explodingkittensû_', 1),
#  ('httpstcotfgrayudc', 1),
#  ('httptcorlnwkeg', 1),
#  ('iwate', 1),
#  ('httptcogmoulzqq', 1),
#  ('httptcovzxoswj', 1),
#  ('httptcomhpnoakb', 1),
#  ('httptcothhjjwpe', 1),
#  ('ayyo', 1),
#  ('dei', 1),
#  ('explosivespacked', 1),
#  ('httptconzackrrji', 1),
#  ('tnwx', 1),
#  ('httptcofwqfckncqw', 1),
#  ('httptcobqtyxda', 1),
#  ('fatherofthree', 1),
#  ('overtaking', 1),
#  ('bathandnortheastsomerset', 1),
#  ('httptcofafcnln', 1),
#  ('httptcouecmcvpk', 1),
#  ('forney', 1),
#  ('developing', 1),
#  ('symptoms', 1),
#  ('httptcorqkkuhey', 1),
#  ('httptconficuloje', 1),
#  ('httptcostfmbbzfb', 1)]

# %% [markdown]
# # BIGRAMS FOR TWEETS (WITH NON STOPWORDS)

# %%
from nltk.util import ngrams

first_5_revs = df['text_clean_non_stopwords']
word_tokens = nltk.word_tokenize(''.join(first_5_revs))
list(ngrams(word_tokens, 2)) #ngrams(word_tokens,n) gives the n-grams.
# Out:
# [('deeds', 'reason'),
#  ('reason', 'earthquake'),
#  ('earthquake', 'may'),
#  ('may', 'allah'),
#  ('allah', 'forgive'),
#  ('forgive', 'usforest'),
#  ('usforest', 'fire'),
#  ('fire', 'near'),
#  ('near', 'la'),
#  ('la', 'ronge'),
#  ('ronge', 'sask'),
#  ('sask', 'canadaresidents'),
#  ('canadaresidents', 'asked'),
#  ('asked', 'shelter'),
#  ('shelter', 'place'),
#  ('place', 'notified'),
#  ('notified', 'officers'),
#  ('officers', 'evacuation'),
#  ('evacuation', 'shelter'),
#  ('shelter', 'place'),
#  ('place', 'orders'),
#  ('orders', 'expectedpeople'),
#  ('expectedpeople', 'receive'),
#  ('receive', 'wildfires'),
#  ('wildfires', 'evacuation'),
#  ('evacuation', 'orders'),
#  ('orders', 'californiagot'),
#  ('californiagot', 'sent'),
#  ('sent', 'photo'),
#  ('photo', 'ruby'),
#  ('ruby', 'alaska'),
#  ('alaska', 'smoke'),
#  ('smoke', 'wildfires'),
#  ('wildfires', 'pours'),
#  ('pours', 'schoolrockyfire'),
#  ('schoolrockyfire', 'update'),
#  ('update', 'california'),
#  ('california', 'hwy'),
#  ('hwy', 'closed'),
#  ('closed', 'directions'),
#  ('directions', 'due'),
#  ('due', 'lake'),
#  ('lake', 'county'),
#  ('county', 'fire'),
#  ('fire', 'cafire'),
#  ('cafire', 'wildfiresflood'),
#  ('wildfiresflood', 'disaster'),
#  ('disaster', 'heavy'),
#  ('heavy', 'rain'),
#  ('rain', 'causes'),
#  ('causes', 'flash'),
#  ('flash', 'flooding'),
#  ('flooding', 'streets'),
#  ('streets', 'manitou'),
#  ('manitou', 'colorado'),
#  ('colorado', 'springs'),
#  ('springs', 'areasim'),
#  ('areasim', 'top'),
#  ('top', 'hill'),
#  ('hill', 'see'),
#  ('see', 'fire'),
#  ('fire', 'woodstheres'),
#  ('woodstheres', 'emergency'),
#  ('emergency', 'evacuation'),
#  ('evacuation', 'happening'),
#  ('happening', 'building'),
#  ('building', 'across'),
#  ('across', 'streetim'),
#  ('streetim', 'afraid'),
#  ('afraid', 'tornado'),
#  ('tornado', 'coming'),
#  ('coming', 'areathree'),
#  ('areathree', 'people'),
#  ('people', 'died'),
#  ('died', 'heat'),
#  ('heat', 'wave'),
#  ('wave', 'farhaha'),
#  ('farhaha', 'south'),
#  ('south', 'tampa'),
#  ('tampa', 'getting'),
#  ('getting', 'flooded'),
#  ('flooded', 'hah'),
#  ('hah', 'wait'),
#  ('wait', 'second'),
#  ('second', 'live'),
#  ('live', 'south'),
#  ('south', 'tampa'),
#  ('tampa', 'gon'),
#  ('gon', 'na'),
#  ('na', 'gon'),
#  ('gon', 'na'),
#  ('na', 'fvck'),
#  ('fvck', 'floodingraining'),
#  ('floodingraining', 'flooding'),
#  ('flooding', 'florida'),
#  ('florida', 'tampabay'),
#  ('tampabay', 'tampa'),
#  ('tampa', 'days'),
#  ('days', 'ive'),
#  ('ive', 'lost'),
#  ('lost', 'countflood'),
#  ('countflood', 'bago'),
#  ('bago', 'myanmar'),
#  ('myanmar', 'arrived'),
#  ('arrived', 'bagodamage'),
#  ('bagodamage', 'school'),
#  ('school', 'bus'),
#  ('bus', 'multi'),
#  ('multi', 'car'),
#  ('car', 'crash'),
#  ('crash', 'breakingwhats'),
#  ('breakingwhats', 'manlove'),
#  ('manlove', 'fruitssummer'),
#  ('fruitssummer', 'lovelycar'),
#  ('lovelycar', 'fastgoooooooaaaaaalridiculouslondon'),
#  ('fastgoooooooaaaaaalridiculouslondon', 'coollove'),
#  ('coollove', 'skiingwonderful'),
#  ('skiingwonderful', 'dayloooooolwayi'),
#  ('dayloooooolwayi', 'cant'),
#  ('cant', 'eat'),
#  ('eat', 'shitnyc'),
#  ('shitnyc', 'last'),
#  ('last', 'weeklove'),
#  ('weeklove', 'girlfriendcoooollike'),
#  ('girlfriendcoooollike', 'pastaendbbcmtd'),
#  ('pastaendbbcmtd', 'wholesale'),
#  ('wholesale', 'markets'),
#  ('markets', 'ablaze'),
#  ('ablaze', 'httptcolhyxeohycalways'),
#  ('httptcolhyxeohycalways', 'try'),
#  ('try', 'bring'),
#  ('bring', 'heavy'),
#  ('heavy', 'metal'),
#  ('metal', 'rt'),
#  ('rt', 'httptcoyaoexngwafricanbaze'),
#  ('httptcoyaoexngwafricanbaze', 'breaking'),
#  ('breaking', 'newsnigeria'),
#  ('newsnigeria', 'flag'),
#  ('flag', 'set'),
#  ('set', 'ablaze'),
#  ('ablaze', 'aba'),
#  ('aba', 'httptconndbgwyeicrying'),
#  ('httptconndbgwyeicrying', 'set'),
#  ('set', 'ablazeplus'),
#  ('ablazeplus', 'side'),
#  ('side', 'look'),
#  ('look', 'sky'),
#  ('sky', 'last'),
#  ('last', 'night'),
#  ('night', 'ablaze'),
#  ('ablaze', 'httptcoqqsmshajnphdsquares'),
#  ('httptcoqqsmshajnphdsquares', 'mufc'),
#  ('mufc', 'theyve'),
#  ('theyve', 'built'),
#  ('built', 'much'),
#  ('much', 'hype'),
#  ('hype', 'around'),
#  ('around', 'new'),
#  ('new', 'acquisitions'),
#  ('acquisitions', 'doubt'),
#  ('doubt', 'set'),
#  ('set', 'epl'),
#  ('epl', 'ablaze'),
#  ('ablaze', 'seasoninec'),
#  ('seasoninec', 'office'),
#  ('office', 'abia'),
#  ('abia', 'set'),
#  ('set', 'ablaze'),
#  ('ablaze', 'httptcoimaomknnabarbados'),
#  ('httptcoimaomknnabarbados', 'bridgetown'),
#  ('bridgetown', 'jamaica'),
#  ('jamaica', 'ûò'),
#  ('ûò', 'two'),
#  ('two', 'cars'),
#  ('cars', 'set'),
#  ('set', 'ablaze'),
#  ('ablaze', 'santa'),
#  ('santa', 'cruz'),
#  ('cruz', 'ûó'),
#  ('ûó', 'head'),
#  ('head', 'st'),
#  ('st', 'elizabeth'),
#  ('elizabeth', 'police'),
#  ('police', 'superintende'),
#  ('superintende', 'httptcowdueajqjablaze'),
#  ('httptcowdueajqjablaze', 'lordcheck'),
#  ('lordcheck', 'httptcoroinsmejj'),
#  ('httptcoroinsmejj', 'httptcotjzjin'),
#  ('httptcotjzjin', 'httptcoyduixefipe'),
#  ('httptcoyduixefipe', 'httptcolxtjckls'),
#  ('httptcolxtjckls', 'nsfwoutside'),
#  ('nsfwoutside', 'youre'),
#  ('youre', 'ablaze'),
#  ('ablaze', 'alive'),
#  ('alive', 'youre'),
#  ('youre', 'dead'),
#  ('dead', 'insideawesome'),
#  ('insideawesome', 'time'),
#  ('time', 'visiting'),
#  ('visiting', 'cfc'),
#  ('cfc', 'head'),
#  ('head', 'office'),
#  ('office', 'ancop'),
#  ('ancop', 'site'),
#  ('site', 'ablaze'),
#  ('ablaze', 'thanks'),
#  ('thanks', 'tita'),
#  ('tita', 'vida'),
#  ('vida', 'taking'),
#  ('taking', 'care'),
#  ('care', 'ussoooo'),
#  ('ussoooo', 'pumped'),
#  ('pumped', 'ablaze'),
#  ('ablaze', 'southridgelifewanted'),
#  ('southridgelifewanted', 'set'),
#  ('set', 'chicago'),
#  ('chicago', 'ablaze'),
#  ('ablaze', 'preaching'),
#  ('preaching', 'hotel'),
#  ('hotel', 'httptcooqknbfofxgained'),
#  ('httptcooqknbfofxgained', 'followers'),
#  ('followers', 'last'),
#  ('last', 'week'),
#  ('week', 'know'),
#  ('know', 'stats'),
#  ('stats', 'grow'),
#  ('grow', 'httptcotiyulifcwest'),
#  ('httptcotiyulifcwest', 'burned'),
#  ('burned', 'thousands'),
#  ('thousands', 'wildfires'),
#  ('wildfires', 'ablaze'),
#  ('ablaze', 'california'),
#  ('california', 'alone'),
#  ('alone', 'httptcovltbrwbrbuilding'),
#  ('httptcovltbrwbrbuilding', 'perfect'),
#  ('perfect', 'tracklist'),
#  ('tracklist', 'life'),
#  ('life', 'leave'),
#  ('leave', 'streets'),
#  ('streets', 'ablazecheck'),
#  ('ablazecheck', 'httptcoroinsmejj'),
#  ('httptcoroinsmejj', 'httptcotjzjin'),
#  ('httptcotjzjin', 'httptcoyduixefipe'),
#  ('httptcoyduixefipe', 'httptcolxtjckls'),
#  ('httptcolxtjckls', 'nsfwfirst'),
#  ('nsfwfirst', 'night'),
#  ('night', 'retainers'),
#  ('retainers', 'quite'),
#  ('quite', 'weird'),
#  ('weird', 'better'),
#  ('better', 'get'),
#  ('get', 'used'),
#  ('used', 'wear'),
#  ('wear', 'every'),
#  ('every', 'single'),
#  ('single', 'night'),
#  ('night', 'next'),
#  ('next', 'year'),
#  ('year', 'leastdeputies'),
#  ('leastdeputies', 'man'),
#  ('man', 'shot'),
#  ('shot', 'brighton'),
#  ('brighton', 'home'),
#  ('home', 'set'),
#  ('set', 'ablaze'),
#  ('ablaze', 'httptcogwnrhmsokman'),
#  ('httptcogwnrhmsokman', 'wife'),
#  ('wife', 'get'),
#  ('get', 'six'),
#  ('six', 'years'),
#  ('years', 'jail'),
#  ('jail', 'setting'),
#  ('setting', 'ablaze'),
#  ('ablaze', 'niece'),
#  ('niece', 'httptcoevahouczasanta'),
#  ('httptcoevahouczasanta', 'cruz'),
#  ('cruz', 'ûó'),
#  ('ûó', 'head'),
#  ('head', 'st'),
#  ('st', 'elizabeth'),
#  ('elizabeth', 'police'),
#  ('police', 'superintendent'),
#  ('superintendent', 'lanford'),
#  ('lanford', 'salmon'),
#  ('salmon', 'r'),
#  ('r', 'httptcovplrhkau'),
#  ('httptcovplrhkau', 'httptcosxhwtnnlfpolice'),
#  ('httptcosxhwtnnlfpolice', 'arsonist'),
#  ('arsonist', 'deliberately'),
#  ('deliberately', 'set'),
#  ('set', 'black'),
#  ('black', 'church'),
#  ('church', 'north'),
#  ('north', 'carolinaåêablaze'),
#  ('carolinaåêablaze', 'httptcopcxarbhannoches'),
#  ('httptcopcxarbhannoches', 'elbestia'),
#  ('elbestia', 'alexis_sanchez'),
#  ('alexis_sanchez', 'happy'),
#  ('happy', 'see'),
#  ('see', 'teammates'),
#  ('teammates', 'training'),
#  ('training', 'hard'),
#  ('hard', 'goodnight'),
#  ('goodnight', 'gunners'),
#  ('gunners', 'httptcoucjjhvgrkurds'),
#  ('httptcoucjjhvgrkurds', 'trampling'),
#  ('trampling', 'turkmen'),
#  ('turkmen', 'flag'),
#  ('flag', 'later'),
#  ('later', 'set'),
#  ('set', 'ablaze'),
#  ('ablaze', 'others'),
#  ('others', 'vandalized'),
#  ('vandalized', 'offices'),
#  ('offices', 'turkmen'),
#  ('turkmen', 'front'),
#  ('front', 'diyala'),
#  ('diyala', 'httptcoizfdyccgtruck'),
#  ('httptcoizfdyccgtruck', 'ablaze'),
#  ('ablaze', 'r'),
#  ('r', 'voortrekker'),
#  ('voortrekker', 'ave'),
#  ('ave', 'outside'),
#  ('outside', 'tambo'),
#  ('tambo', 'intl'),
#  ('intl', 'cargo'),
#  ('cargo', 'section'),
#  ('section', 'httptcokscqkfkkfset'),
#  ('httptcokscqkfkkfset', 'hearts'),
#  ('hearts', 'ablaze'),
#  ('ablaze', 'every'),
#  ('every', 'city'),
#  ('city', 'gift'),
#  ('gift', 'every'),
#  ('every', 'skyline'),
#  ('skyline', 'like'),
#  ('like', 'kiss'),
#  ('kiss', 'upon'),
#  ('upon', 'lips'),
#  ('lips', 'û_'),
#  ('û_', 'httpstcocyompzazsky'),
#  ('httpstcocyompzazsky', 'ablaze'),
#  ('ablaze', 'tonight'),
#  ('tonight', 'los'),
#  ('los', 'angeles'),
#  ('angeles', 'im'),
#  ('im', 'expecting'),
#  ('expecting', 'ig'),
#  ('ig', 'fb'),
#  ('fb', 'filled'),
#  ('filled', 'sunset'),
#  ('sunset', 'shots'),
#  ('shots', 'know'),
#  ('know', 'peepswest'),
#  ('peepswest', 'burned'),
#  ('burned', 'thousands'),
#  ('thousands', 'wildfires'),
#  ('wildfires', 'ablaze'),
#  ('ablaze', 'california'),
#  ('california', 'alone'),
#  ('alone', 'httptcoicsjgzte'),
#  ('httptcoicsjgzte', 'climate'),
#  ('climate', 'energy'),
#  ('energy', 'httptcofxmnlbdrevel'),
#  ('httptcofxmnlbdrevel', 'wmv'),
#  ('wmv', 'videos'),
#  ('videos', 'means'),
#  ('means', 'mac'),
#  ('mac', 'farewell'),
#  ('farewell', 'ablaze'),
#  ('ablaze', 'wmv'),
#  ('wmv', 'en'),
#  ('en', 'route'),
#  ('route', 'dvd'),
#  ('dvd', 'gtxrwmprogressive'),
#  ('gtxrwmprogressive', 'greetings'),
#  ('greetings', 'month'),
#  ('month', 'students'),
#  ('students', 'would'),
#  ('would', 'set'),
#  ('set', 'pens'),
#  ('pens', 'ablaze'),
#  ('ablaze', 'torch'),
#  ('torch', 'publications'),
#  ('publications', 'httptcofxpixqujtrene'),
#  ('httptcofxpixqujtrene', 'ablaze'),
#  ('ablaze', 'amp'),
#  ('amp', 'jacinta'),
#  ('jacinta', 'secret'),
#  ('secret', 'k'),
#  ('k', 'fallen'),
#  ('fallen', 'skies'),
#  ('skies', 'edit'),
#  ('edit', 'mar'),
#  ('mar', 'httpstcomlmsuzvznavista'),
#  ('httpstcomlmsuzvznavista', 'steve'),
#  ('steve', 'fires'),
#  ('fires', 'something'),
#  ('something', 'else'),
#  ('else', 'california'),
#  ('california', 'tinderbox'),
#  ('tinderbox', 'clown'),
#  ('clown', 'setting'),
#  ('setting', 'hood'),
#  ('hood', 'ablaze'),
#  ('ablaze', 'newsnowplaying'),
#  ('newsnowplaying', 'rene'),
#  ('rene', 'ablaze'),
#  ('ablaze', 'amp'),
#  ('amp', 'ian'),
#  ('ian', 'buff'),
#  ('buff', 'magnitude'),
#  ('magnitude', 'httptcoavjsjfftc'),
#  ('httptcoavjsjfftc', 'edmnxwestmidlands'),
#  ('edmnxwestmidlands', 'huge'),
#  ('huge', 'fire'),
#  ('fire', 'wholesale'),
#  ('wholesale', 'markets'),
#  ('markets', 'ablaze'),
#  ('ablaze', 'httptcorwzbfvnxerablaze'),
#  ('httptcorwzbfvnxerablaze', 'time'),
#  ('time', 'talk'),
#  ('talk', 'go'),
#  ('go', 'dont'),
#  ('dont', 'know'),
#  ('know', 'make'),
#  ('make', 'due'),
#  ('due', 'workcant'),
#  ('workcant', 'kids'),
#  ('kids', 'cuz'),
#  ('cuz', 'got'),
#  ('got', 'bicycle'),
#  ('bicycle', 'accident'),
#  ('accident', 'amp'),
#  ('amp', 'split'),
#  ('split', 'testicles'),
#  ('testicles', 'impossible'),
#  ('impossible', 'kids'),
#  ('kids', 'michael'),
#  ('michael', 'fatheraccident'),
#  ('fatheraccident', 'w'),
#  ('w', 'nashvilletraffic'),
#  ('nashvilletraffic', 'traffic'),
#  ('traffic', 'moving'),
#  ('moving', 'slower'),
#  ('slower', 'usual'),
#  ('usual', 'httpstcoghkegjaccident'),
#  ('httpstcoghkegjaccident', 'center'),
#  ('center', 'lane'),
#  ('lane', 'blocked'),
#  ('blocked', 'santaclara'),
#  ('santaclara', 'us'),
#  ('us', 'nb'),
#  ('nb', 'great'),
#  ('great', 'america'),
#  ('america', 'pkwy'),
#  ('pkwy', 'bayarea'),
#  ('bayarea', 'traffic'),
#  ('traffic', 'httptcopmlohzurwrhttptcogkyegjtk'),
#  ('httptcopmlohzurwrhttptcogkyegjtk', 'personalinjury'),
#  ('personalinjury', 'accident'),
#  ('accident', 'summer'),
#  ('summer', 'read'),
#  ('read', 'advice'),
#  ('advice', 'amp'),
#  ('amp', 'see'),
#  ('see', 'solicitor'),
#  ('solicitor', 'help'),
#  ('help', 'otleyhourstlouis'),
#  ('otleyhourstlouis', 'caraccidentlawyer'),
#  ('caraccidentlawyer', 'speeding'),
#  ('speeding', 'among'),
#  ('among', 'top'),
#  ('top', 'causes'),
#  ('causes', 'teen'),
#  ('teen', 'accidents'),
#  ('accidents', 'httpstcokzomof'),
#  ('httpstcokzomof', 'httpstcoskxvmcba'),
#  ('httpstcoskxvmcba', 'car'),
#  ('car', 'accident'),
#  ('accident', 'teeû_reported'),
#  ('teeû_reported', 'motor'),
#  ('motor', 'vehicle'),
#  ('vehicle', 'accident'),
#  ('accident', 'curry'),
#  ('curry', 'herman'),
#  ('herman', 'rd'),
#  ('rd', 'near'),
#  ('near', 'stephenson'),
#  ('stephenson', 'involving'),
#  ('involving', 'overturned'),
#  ('overturned', 'vehicle'),
#  ('vehicle', 'please'),
#  ('please', 'use'),
#  ('use', 'httptcoybjezkurwbigrigradio'),
#  ('httptcoybjezkurwbigrigradio', 'live'),
#  ('live', 'accident'),
#  ('accident', 'awarenessmile'),
#  ('awarenessmile', 'marker'),
#  ('marker', 'south'),
#  ('south', 'mooresville'),
#  ('mooresville', 'iredell'),
#  ('iredell', 'vehicle'),
#  ('vehicle', 'accident'),
#  ('accident', 'ramp'),
#  ('ramp', 'closed'),
#  ('closed', 'pmrt'),
#  ('pmrt', 'sleepjunkies'),
#  ('sleepjunkies', 'sleeping'),
#  ('sleeping', 'pills'),
#  ('pills', 'double'),
#  ('double', 'risk'),
#  ('risk', 'car'),
#  ('car', 'accident'),
#  ('accident', 'httptcosnmfictaccident'),
#  ('httptcosnmfictaccident', 'knew'),
#  ('knew', 'gon'),
#  ('gon', 'happen'),
#  ('happen', 'httpstcoysxunvcehtraffic'),
#  ('httpstcoysxunvcehtraffic', 'accident'),
#  ('accident', 'n'),
#  ('n', 'cabrillo'),
#  ('cabrillo', 'hwymagellan'),
#  ('hwymagellan', 'av'),
#  ('av', 'mirmile'),
#  ('mirmile', 'marker'),
#  ('marker', 'south'),
#  ('south', 'mooresville'),
#  ('mooresville', 'iredell'),
#  ('iredell', 'vehicle'),
#  ('vehicle', 'accident'),
#  ('accident', 'congestion'),
#  ('congestion', 'pmpastor'),
#  ('pmpastor', 'scene'),
#  ('scene', 'accidentwho'),
#  ('accidentwho', 'owner'),
#  ('owner', 'range'),
#  ('range', 'rovermom'),
#  ('rovermom', 'didnt'),
#  ('didnt', 'get'),
#  ('get', 'home'),
#  ('home', 'fast'),
#  ('fast', 'wished'),
#  ('wished', 'mom'),
#  ('mom', 'accident'),
#  ('accident', 'truck'),
#  ('truck', 'spilt'),
#  ('spilt', 'mayonnaisehorrible'),
#  ('mayonnaisehorrible', 'car'),
#  ('car', 'accident'),
#  ('accident', 'past'),
#  ('past', 'sunday'),
#  ('sunday', 'im'),
#  ('im', 'finally'),
#  ('finally', 'able'),
#  ('able', 'get'),
#  ('get', 'around'),
#  ('around', 'thank'),
#  ('thank', 'godwait'),
#  ('godwait', 'see'),
#  ('see', 'pissed'),
#  ('pissed', 'donnie'),
#  ('donnie', 'tell'),
#  ('tell', 'another'),
#  ('another', 'accidenttruckcrash'),
#  ('accidenttruckcrash', 'overturns'),
#  ('overturns', 'fortworth'),
#  ('fortworth', 'interstate'),
#  ('interstate', 'httptcorsljqfp'),
#  ('httptcorsljqfp', 'click'),
#  ('click', 'youve'),
#  ('youve', 'crashgthttptcolduniywkaccident'),
#  ('crashgthttptcolduniywkaccident', 'ashville'),
#  ('ashville', 'us'),
#  ('us', 'sb'),
#  ('sb', 'sr'),
#  ('sr', 'traffic'),
#  ('traffic', 'httptcohylmowgficarolina'),
#  ('httptcohylmowgficarolina', 'accident'),
#  ('accident', 'motorcyclist'),
#  ('motorcyclist', 'dies'),
#  ('dies', 'crash'),
#  ('crash', 'car'),
#  ('car', 'crossed'),
#  ('crossed', 'median'),
#  ('median', 'motorcycle'),
#  ('motorcycle', 'rider'),
#  ('rider', 'traveling'),
#  ('traveling', 'httptcoplzrlmyfyi'),
#  ('httptcoplzrlmyfyi', 'cadfyi'),
#  ('cadfyi', 'accident'),
#  ('accident', 'property'),
#  ('property', 'damagenhs'),
#  ('damagenhs', 'piner'),
#  ('piner', 'rdhorndale'),
#  ('rdhorndale', 'drrt'),
#  ('drrt', 'naayf'),
#  ('naayf', 'first'),
#  ('first', 'accident'),
#  ('accident', 'years'),
#  ('years', 'turning'),
#  ('turning', 'onto'),
#  ('onto', 'chandanee'),
#  ('chandanee', 'magu'),
#  ('magu', 'near'),
#  ('near', 'mma'),
#  ('mma', 'taxi'),
#  ('taxi', 'rammed'),
#  ('rammed', 'halfway'),
#  ('halfway', 'turned'),
#  ('turned', 'everyone'),
#  ('everyone', 'confû_accident'),
#  ('confû_accident', 'left'),
#  ('left', 'lane'),
#  ('lane', 'blocked'),
#  ('blocked', 'manchester'),
#  ('manchester', 'rt'),
#  ('rt', 'nb'),
#  ('nb', 'eddy'),
#  ('eddy', 'rd'),
#  ('rd', 'stop'),
#  ('stop', 'go'),
#  ('go', 'traffic'),
#  ('traffic', 'back'),
#  ('back', 'nha'),
#  ('nha', 'delay'),
#  ('delay', 'mins'),
#  ('mins', 'trafficaccident'),
#  ('trafficaccident', 'property'),
#  ('property', 'damage'),
#  ('damage', 'piner'),
#  ('piner', 'rdhorndale'),
#  ('rdhorndale', 'draccident'),
#  ('draccident', 'httptcooiafxigmfyi'),
#  ('httptcooiafxigmfyi', 'cadfyi'),
#  ('cadfyi', 'accident'),
#  ('accident', 'property'),
#  ('property', 'damagewpd'),
#  ('damagewpd', 'th'),
#  ('th', 'stpm'),
#  ('stpm', 'traffic'),
#  ('traffic', 'accident'),
#  ('accident', 'injury'),
#  ('injury', 'willis'),
#  ('willis', 'foreman'),
#  ('foreman', 'rd'),
#  ('rd', 'httptcovckitedevaashiqui'),
#  ('httptcovckitedevaashiqui', 'actress'),
#  ('actress', 'anu'),
#  ('anu', 'aggarwal'),
#  ('aggarwal', 'nearfatal'),
#  ('nearfatal', 'accident'),
#  ('accident', 'httptcootfplqwsuffield'),
#  ('httptcootfplqwsuffield', 'alberta'),
#  ('alberta', 'accident'),
#  ('accident', 'httpstcobptmlfpmile'),
#  ('httpstcobptmlfpmile', 'backup'),
#  ('backup', 'southaccident'),
#  ('southaccident', 'blocking'),
#  ('blocking', 'right'),
#  ('right', 'lanes'),
#  ('lanes', 'exit'),
#  ('exit', 'langtree'),
#  ('langtree', 'rdconsider'),
#  ('rdconsider', 'nc'),
#  ('nc', 'nc'),
#  ('nc', 'nc'),
#  ('nc', 'alternateaccident'),
#  ('alternateaccident', 'changed'),
#  ('changed', 'life'),
#  ('life', 'help'),
#  ('help', 'determine'),
#  ('determine', 'options'),
#  ('options', 'financially'),
#  ('financially', 'support'),
#  ('support', 'life'),
#  ('life', 'care'),
#  ('care', 'plans'),
#  ('plans', 'ongoing'),
#  ('ongoing', 'treatmentbreaking'),
#  ('treatmentbreaking', 'deadly'),
#  ('deadly', 'motorcycle'),
#  ('motorcycle', 'car'),
#  ('car', 'accident'),
#  ('accident', 'happened'),
#  ('happened', 'hagerstown'),
#  ('hagerstown', 'today'),
#  ('today', 'ill'),
#  ('ill', 'details'),
#  ('details', 'yourstate'),
#  ('yourstate', 'whagflowri'),
#  ('whagflowri', 'marinading'),
#  ('marinading', 'accidentcar'),
#  ('accidentcar', 'even'),
#  ('even', 'week'),
#  ('week', 'got'),
#  ('got', 'fucking'),
#  ('fucking', 'car'),
#  ('car', 'accident'),
#  ('accident', 'mfs'),
#  ('mfs', 'cant'),
#  ('cant', 'fucking'),
#  ('fucking', 'drivenorwaymfa'),
#  ('drivenorwaymfa', 'bahrain'),
#  ('bahrain', 'police'),
#  ('police', 'previously'),
#  ('previously', 'died'),
#  ('died', 'road'),
#  ('road', 'accident'),
#  ('accident', 'killed'),
#  ('killed', 'explosion'),
#  ('explosion', 'httpstcogfjfgtodadstill'),
#  ('httpstcogfjfgtodadstill', 'heard'),
#  ('heard', 'church'),
#  ('church', 'leaders'),
#  ('leaders', 'kenya'),
#  ('kenya', 'coming'),
#  ('coming', 'forward'),
#  ('forward', 'comment'),
#  ('comment', 'accident'),
#  ('accident', 'issue'),
#  ('issue', 'disciplinary'),
#  ('disciplinary', 'measuresarrestpastorngangaaftershock_delo'),
#  ('measuresarrestpastorngangaaftershock_delo', 'scuf'),
#  ('scuf', 'ps'),
#  ('ps', 'live'),
#  ('live', 'game'),
#  ('game', 'cyaman'),
#  ('cyaman', 'drive'),
#  ('drive', 'effort'),
#  ('effort', 'gets'),
#  ('gets', 'painful'),
#  ('painful', 'man'),
#  ('man', 'win'),
#  ('win', 'roger'),
#  ('roger', 'bannisterir'),
#  ('bannisterir', 'icemoon'),
#  ('icemoon', 'aftershock'),
#  ('aftershock', 'httptcoynxnvvkcda'),
#  ('httptcoynxnvvkcda', 'djicemoon'),
#  ('djicemoon', 'dubstep'),
#  ('dubstep', 'trapmusic'),
#  ('trapmusic', 'dnb'),
#  ('dnb', 'edm'),
#  ('edm', 'dance'),
#  ('dance', 'icesû_'),
#  ('icesû_', 'httptcoweqpesenkuvictory'),
#  ('httptcoweqpesenkuvictory', 'bargain'),
#  ('bargain', 'basement'),
#  ('basement', 'prices'),
#  ('prices', 'dwight'),
#  ('dwight', 'david'),
#  ('david', 'eisenhowerir'),
#  ('eisenhowerir', 'icemoon'),
#  ('icemoon', 'aftershock'),
#  ('aftershock', 'httptcovampodgyw'),
#  ('httptcovampodgyw', 'djicemoon'),
#  ('djicemoon', 'dubstep'),
#  ('dubstep', 'trapmusic'),
#  ('trapmusic', 'dnb'),
#  ('dnb', 'edm'),
#  ('edm', 'dance'),
#  ('dance', 'icesû_'),
#  ('icesû_', 'httptcozevakjapcznobody'),
#  ('httptcozevakjapcznobody', 'remembers'),
#  ('remembers', 'came'),
#  ('came', 'second'),
#  ('second', 'charles'),
#  ('charles', 'schulzaftershock_delo'),
#  ('schulzaftershock_delo', 'im'),
#  ('im', 'speaking'),
#  ('speaking', 'someone'),
#  ('someone', 'using'),
#  ('using', 'scuf'),
#  ('scuf', 'xb'),
#  ('xb', 'people'),
#  ('people', 'end'),
#  ('end', 'getting'),
#  ('getting', 'ps'),
#  ('ps', 'alsoharder'),
#  ('alsoharder', 'conflict'),
#  ('conflict', 'glorious'),
#  ('glorious', 'triumph'),
#  ('triumph', 'thomas'),
#  ('thomas', 'painegrowingupspoiled'),
#  ('painegrowingupspoiled', 'going'),
#  ('going', 'clay'),
#  ('clay', 'pigeon'),
#  ('pigeon', 'shooting'),
#  ('shooting', 'crying'),
#  ('crying', 'aftershockguess'),
#  ('aftershockguess', 'one'),
#  ('one', 'actually'),
#  ('actually', 'wants'),
#  ('wants', 'free'),
#  ('free', 'aftershock'),
#  ('aftershock', 'tcaftershock'),
#  ('tcaftershock', 'terrifying'),
#  ('terrifying', 'best'),
#  ('best', 'roller'),
#  ('roller', 'coaster'),
#  ('coaster', 'ive'),
#  ('ive', 'ever'),
#  ('ever', 'disclaimer'),
#  ('disclaimer', 'iveaftershock'),
#  ('iveaftershock', 'httpstcoxmwodfmtuiir'),
#  ('httpstcoxmwodfmtuiir', 'icemoon'),
#  ('icemoon', 'aftershock'),
#  ('aftershock', 'httptcomjdzmgjow'),
#  ('httptcomjdzmgjow', 'djicemoon'),
#  ('djicemoon', 'dubstep'),
#  ('dubstep', 'trapmusic'),
#  ('trapmusic', 'dnb'),
#  ('dnb', 'edm'),
#  ('edm', 'dance'),
#  ('dance', 'icesû_'),
#  ('icesû_', 'httptconuhasfkbvir'),
#  ('httptconuhasfkbvir', 'icemoon'),
#  ('icemoon', 'aftershock'),
#  ('aftershock', 'httptcovampodgyw'),
#  ('httptcovampodgyw', 'djicemoon'),
#  ('djicemoon', 'dubstep'),
#  ('dubstep', 'trapmusic'),
#  ('trapmusic', 'dnb'),
#  ('dnb', 'edm'),
#  ('edm', 'dance'),
#  ('dance', 'icesû_'),
#  ('icesû_', 'httptcozevakjapczir'),
#  ('httptcozevakjapczir', 'icemoon'),
#  ('icemoon', 'aftershock'),
#  ('aftershock', 'httptcoeepzhoth'),
#  ('httptcoeepzhoth', 'djicemoon'),
#  ('djicemoon', 'dubstep'),
#  ('dubstep', 'trapmusic'),
#  ('trapmusic', 'dnb'),
#  ('dnb', 'edm'),
#  ('edm', 'dance'),
#  ('dance', 'icesû_'),
#  ('icesû_', 'httptcoaddoqkjfordays'),
#  ('httptcoaddoqkjfordays', 'im'),
#  ('im', 'seeing'),
#  ('seeing', 'issues'),
#  ('issues', 'aftershockir'),
#  ('aftershockir', 'icemoon'),
#  ('icemoon', 'aftershock'),
#  ('aftershock', 'httptcothyzomvwu'),
#  ('httptcothyzomvwu', 'djicemoon'),
#  ('djicemoon', 'dubstep'),
#  ('dubstep', 'trapmusic'),
#  ('trapmusic', 'dnb'),
#  ('dnb', 'edm'),
#  ('edm', 'dance'),
#  ('dance', 'icesû_'),
#  ('icesû_', 'httptcojooxkir'),
#  ('httptcojooxkir', 'icemoon'),
#  ('icemoon', 'aftershock'),
#  ('aftershock', 'httptcothyzomvwu'),
#  ('httptcothyzomvwu', 'djicemoon'),
#  ('djicemoon', 'dubstep'),
#  ('dubstep', 'trapmusic'),
#  ('trapmusic', 'dnb'),
#  ('dnb', 'edm'),
#  ('edm', 'dance'),
#  ('dance', 'icesû_'),
#  ('icesû_', 'httptcojooxkwisdomwed'),
#  ('httptcojooxkwisdomwed', 'bonus'),
#  ('bonus', 'minute'),
#  ('minute', 'daily'),
#  ('daily', 'habits'),
#  ('habits', 'could'),
#  ('could', 'really'),
#  ('really', 'improve'),
#  ('improve', 'life'),
#  ('life', 'many'),
#  ('many', 'already'),
#  ('already', 'lifehacks'),
#  ('lifehacks', 'httptcotbmfqbcwaftershock'),
#  ('httptcotbmfqbcwaftershock', 'protect'),
#  ('protect', 'profit'),
#  ('profit', 'next'),
#  ('next', 'global'),
#  ('global', 'financial'),
#  ('financial', 'meltdown'),
#  ('meltdown', 'david'),
#  ('david', 'wiedemer'),
#  ('wiedemer', 'http'),
#  ('http', 'httptcowztzhgmvqmoment'),
#  ('httptcowztzhgmvqmoment', 'get'),
#  ('get', 'scary'),
#  ('scary', 'roller'),
#  ('roller', 'coaster'),
#  ('coaster', 'guy'),
#  ('guy', 'behind'),
#  ('behind', 'screaming'),
#  ('screaming', 'bloody'),
#  ('bloody', 'murder'),
#  ('murder', 'silverwood'),
#  ('silverwood', 'aftershockaftershock'),
#  ('aftershockaftershock', 'ã'),
#  ('ã', 'fullã'),
#  ('fullã', 'streaming'),
#  ('streaming', 'youtube'),
#  ('youtube', 'httptcovveusesgfgtgt'),
#  ('httptcovveusesgfgtgt', 'aftershock'),
#  ('aftershock', 'protect'),
#  ('protect', 'profit'),
#  ('profit', 'next'),
#  ('next', 'global'),
#  ('global', 'financial'),
#  ('financial', 'book'),
#  ('book', 'httptcofntucz'),
#  ('httptcofntucz', 'esquireattiresometimes'),
#  ('esquireattiresometimes', 'face'),
#  ('face', 'difficulties'),
#  ('difficulties', 'youre'),
#  ('youre', 'something'),
#  ('something', 'wrong'),
#  ('wrong', 'youre'),
#  ('youre', 'something'),
#  ('something', 'right'),
#  ('right', 'joel'),
#  ('joel', 'osteenthing'),
#  ('osteenthing', 'stands'),
#  ('stands', 'dream'),
#  ('dream', 'try'),
#  ('try', 'belief'),
#  ('belief', 'actually'),
#  ('actually', 'possible'),
#  ('possible', 'joel'),
#  ('joel', 'brownpraise'),
#  ('brownpraise', 'god'),
#  ('god', 'ministry'),
#  ('ministry', 'tells'),
#  ('tells', 'like'),
#  ('like', 'wdyouth'),
#  ('wdyouth', 'biblestudy'),
#  ('biblestudy', 'httpstcoujkegbccremembering'),
#  ('httpstcoujkegbccremembering', 'going'),
#  ('going', 'die'),
#  ('die', 'best'),
#  ('best', 'way'),
#  ('way', 'know'),
#  ('know', 'avoid'),
#  ('avoid', 'trap'),
#  ('trap', 'thinking'),
#  ('thinking', 'something'),
#  ('something', 'lose'),
#  ('lose', 'ûò'),
#  ('ûò', 'steve'),
#  ('steve', 'jobstried'),
#  ('jobstried', 'orange'),
#  ('orange', 'aftershock'),
#  ('aftershock', 'today'),
#  ('today', 'life'),
#  ('life', 'neveronfireanders'),
#  ('neveronfireanders', 'love'),
#  ('love', 'bbaftershock'),
#  ('bbaftershock', 'httpstcojvppkhjyaftershock'),
#  ('httpstcojvppkhjyaftershock', 'back'),
#  ('back', 'school'),
#  ('school', 'kick'),
#  ('kick', 'great'),
#  ('great', 'want'),
#  ('want', 'thank'),
#  ('thank', 'everyone'),
#  ('everyone', 'making'),
#  ('making', 'possible'),
#  ('possible', 'great'),
#  ('great', 'nightpeople'),
#  ('nightpeople', 'say'),
#  ('say', 'done'),
#  ('done', 'interrupt'),
#  ('interrupt', 'ûò'),
#  ('ûò', 'george'),
#  ('george', 'bernard'),
#  ('bernard', 'shawfirst'),
#  ('shawfirst', 'man'),
#  ('man', 'gets'),
#  ('gets', 'oyster'),
#  ('oyster', 'second'),
#  ('second', 'man'),
#  ('man', 'gets'),
#  ('gets', 'shell'),
#  ('shell', 'andrew'),
#  ('andrew', 'carnegieanyone'),
#  ('carnegieanyone', 'need'),
#  ('need', 'pu'),
#  ('pu', 'tonight'),
#  ('tonight', 'play'),
#  ('play', 'hybrid'),
#  ('hybrid', 'slayer'),
#  ('slayer', 'ps'),
#  ('ps', 'eu'),
#  ('eu', 'hmu'),
#  ('hmu', 'codsandscrims'),
#  ('codsandscrims', 'empirikgaming'),
#  ('empirikgaming', 'codawscrims'),
#  ('codawscrims', 'tp_kotc'),
#  ('tp_kotc', 'tpfa'),
#  ('tpfa', 'aftershock_orgexperts'),
#  ...]

# %% [markdown]
# ## Summary
# - First of all, we imported all the libraries that would be useful to analyze the information of the datasets (pandas, numpy, matplotlib, etc)
#
# - Then, we uploaded the two datasets (train and test datasets) into our notebook and we gave a basic description of it, describing its columns and summarizing some important information for our case, like the most repetitive target in the data (0: not disaster)
#
# - Thirdly, we cleaned the data, in order to extract the most valuable information from it. We removed rows, which do not have 1 and 0 values in target column, punctuations, numbers, uppercase, hyperlinks and square brackets.
#
# - For the feature engineering section, we added some useful columns such as: number of words in the tweets and text length (total characters). We found out that this dataset was probably made before 2017, when the tweet limit was 140 characters. Regarding location, we saw that it is important to standarize some words that are different but refer to the same country (USA and United States for example).
#
# - Finally, we analyze the data, using some useful visualizations such as: histograms, barplots and word clouds graphs, focusing on the most repetitive words. Here we found an important opportunity with “stop words” that are popular in most of the tweets, but without a context do not give us a lot of information.

# %% [markdown]
# ### Repository
# https://github.com/oscarciceri/Disaster_Monitoring_Based_On_Tweets/blob/main/EDA.ipynb
